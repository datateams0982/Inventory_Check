# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np # linear algebra
import pandas as pd
# from tqdm import tqdm
from tqdm import tqdm_notebook as tqdm
# tqdm.pandas()

# %%
data = pd.read_csv('D:\\庫存健診開發\\data\\Stock\\TWSE_Stock.csv', converters={'ts': str, 'StockNo': str, 'StockName': str})
data['ts'] = pd.to_datetime(data['ts'])
data
# Out:
#         StockName StockNo  close  high   low  open  return         total  \
# 0              台泥    1101   19.3  19.9  19.1  19.9     NaN  8.756613e+08
# 1              台泥    1101   18.7  19.6  18.4  19.4    -0.6  7.295642e+08
# 2              台泥    1101   20.0  20.0  18.9  19.0     1.3  1.200960e+09
# 3              台泥    1101   21.0  21.4  20.0  20.0     1.0  3.204683e+09
# 4              台泥    1101   21.0  21.3  20.4  21.0     0.0  1.477319e+09
# ...           ...     ...    ...   ...   ...   ...     ...           ...
# 2874548       世紀鋼    9958   77.3  78.9  77.1  78.9    -0.2  2.371908e+08
# 2874549       世紀鋼    9958   77.7  79.3  77.5  77.9     0.4  4.648791e+08
# 2874550       世紀鋼    9958   76.3  78.4  76.2  78.4    -1.4  3.086962e+08
# 2874551       世紀鋼    9958   75.8  77.0  75.8  76.6    -0.5  1.328813e+08
# 2874552       世紀鋼    9958   75.8  76.5  75.4  75.8     0.0  1.161456e+08
#
#                 ts          vol              On_Date
# 0       2004-02-11   44990547.0           1962-02-09
# 1       2004-02-12   38283630.0           1962-02-09
# 2       2004-02-13   60809947.0           1962-02-09
# 3       2004-02-16  154068407.0           1962-02-09
# 4       2004-02-17   70709589.0           1962-02-09
# ...            ...          ...                  ...
# 2874548 2019-09-17    3050500.0  2008-03-12 00:00:00
# 2874549 2019-09-18    5940537.0  2008-03-12 00:00:00
# 2874550 2019-09-19    4011923.0  2008-03-12 00:00:00
# 2874551 2019-09-20    1742684.0  2008-03-12 00:00:00
# 2874552 2019-09-23    1530090.0  2008-03-12 00:00:00
#
# [2874553 rows x 11 columns]

# %%
df_list = [group[1] for group in data.groupby(data['StockNo'])][:10]
for dataset in df_list:
    x_ = range(3, dataset.shape[0])

    x_ =list(dataset.index)
    plt.figure(figsize=(30,10))
    plt.plot(dataset['ma7'],label='MA 7', color='g',linestyle='--')

    plt.plot(dataset['close'],label='Closing Price', color='b')


 
    plt.plot(dataset['ma21'],label='MA 21', color='r',linestyle='--')

    plt.plot(dataset['upper_band'],label='Upper Band', color='c')

    plt.plot(dataset['lower_band'],label='Lower Band', color='c')

    plt.fill_between(x_, dataset['lower_band'], dataset['upper_band'], alpha=0.35)

    plt.title('Technical indicators for Goldman Sachs')

    plt.ylabel('NTD')

# %%
def Close_normalize(data, Start, End, feature='close', scale=True):
    delta = End - Start  
    dates = [Start + timedelta(days=x) for x in range((End-Start).days)]

    df = data[data.ts.isin(dates)]
    df_list = [group[1] for group in df.groupby(df['StockNo'])]

    train_list = []
    val_list = []
    for i, d in enumerate(tqdm(df_list, total=len(df_list))):
        
        d['On_Date'] = pd.to_datetime(d['On_Date'])
        if d['On_Date'].iloc[0] > Start:
            continue
        
        d = d.sort_values(by='ts').reset_index(drop=True)
        sc = MinMaxScaler(feature_range = (0, 1))
        a = sc.fit_transform(np.array(d[feature]).reshape(len(d), 1))
        d['close'] = a
        
        if i < 0.9*len(df_list):
            train_list.append(a.tolist())
        else:
            val_list.append(a.tolist())

    return train_list, val_list

# %%
from datetime import datetime, timedelta, date
X_train, X_val = Close_normalize(data, date(2004,4,1), date(2016,9,1))
# Out:
# HBox(children=(IntProgress(value=0, max=862), HTML(value='')))

# %%
np.array(X_train).shape
# Out:
# (525, 3080, 1)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, Flatten, TimeDistributed, LeakyReLU, Conv1D, BatchNormalization, MaxPooling1D, AveragePooling1D, UpSampling1D
from tensorflow.keras.models import Model, Sequential
from tensorflow.compat.v1.keras.layers import CuDNNLSTM
from tensorflow.keras import layers, optimizers
from tensorflow.keras.callbacks import EarlyStopping

# %%
input_window = Input(shape=(np.array(X_train).shape[1],1))
x = Conv1D(16, 3, activation="relu", padding="same")(input_window) # 10 dims
x = MaxPooling1D(2, padding="same")(x) # 5 dims
x = Conv1D(1, 3, activation="relu", padding="same")(x) # 5 dims
encoded = MaxPooling1D(2, padding="same")(x) # 3 dims

encoder = Model(input_window, encoded)

x = Conv1D(1, 3, activation="relu", padding="same")(encoded) # 3 dims
#x = BatchNormalization()(x)
x = UpSampling1D(2)(x) # 6 dims
x = Conv1D(16, 2, activation='relu', padding='same')(x) # 5 dims
#x = BatchNormalization()(x)
x = UpSampling1D(2)(x) # 10 dims
decoded = Conv1D(1, 3, activation='sigmoid', padding='same')(x) # 10 dims
autoencoder = Model(input_window, decoded)
autoencoder.summary()

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
history = autoencoder.fit(np.array(X_train), np.array(X_train),
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(np.array(X_val), np.array(X_val)))
# Out:
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 3080, 1)]         0
# _________________________________________________________________
# conv1d_28 (Conv1D)           (None, 3080, 16)          64
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 1540, 16)          0
# _________________________________________________________________
# conv1d_29 (Conv1D)           (None, 1540, 1)           49
# _________________________________________________________________
# max_pooling1d_13 (MaxPooling (None, 770, 1)            0
# _________________________________________________________________
# conv1d_30 (Conv1D)           (None, 770, 1)            4
# _________________________________________________________________
# up_sampling1d_10 (UpSampling (None, 1540, 1)           0
# _________________________________________________________________
# conv1d_31 (Conv1D)           (None, 1540, 16)          48
# _________________________________________________________________
# up_sampling1d_11 (UpSampling (None, 3080, 16)          0
# _________________________________________________________________
# conv1d_32 (Conv1D)           (None, 3080, 1)           49
# =================================================================
# Total params: 214
# Trainable params: 214
# Non-trainable params: 0
# _________________________________________________________________
# Train on 525 samples, validate on 39 samples
# Epoch 1/100
# Epoch 86/100
# 525/525 [==============================] - ETA: 0s - loss: 0.530 - 0s 213us/sample - loss: 0.5331 - val_loss: 0.5240
# Epoch 87/100
# 525/525 [==============================] - ETA: 0s - loss: 0.533 - 0s 213us/sample - loss: 0.5328 - val_loss: 0.5237
# Epoch 88/100
# 525/525 [==============================] - ETA: 0s - loss: 0.528 - 0s 209us/sample - loss: 0.5327 - val_loss: 0.5234
# Epoch 89/100
# 525/525 [==============================] - ETA: 0s - loss: 0.530 - 0s 213us/sample - loss: 0.5325 - val_loss: 0.5231
# Epoch 90/100
# 525/525 [==============================] - ETA: 0s - loss: 0.530 - 0s 215us/sample - loss: 0.5323 - val_loss: 0.5229
# Epoch 91/100
# 525/525 [==============================] - ETA: 0s - loss: 0.535 - 0s 207us/sample - loss: 0.5321 - val_loss: 0.5226
# Epoch 92/100
# 525/525 [==============================] - ETA: 0s - loss: 0.529 - 0s 209us/sample - loss: 0.5319 - val_loss: 0.5223
# Epoch 93/100
# 525/525 [==============================] - ETA: 0s - loss: 0.532 - 0s 207us/sample - loss: 0.5318 - val_loss: 0.5221
# Epoch 94/100
# 525/525 [==============================] - ETA: 0s - loss: 0.530 - 0s 215us/sample - loss: 0.5316 - val_loss: 0.5218
# Epoch 95/100
# 525/525 [==============================] - ETA: 0s - loss: 0.531 - 0s 211us/sample - loss: 0.5314 - val_loss: 0.5216
# Epoch 96/100
# 525/525 [==============================] - ETA: 0s - loss: 0.539 - 0s 215us/sample - loss: 0.5312 - val_loss: 0.5213
# Epoch 97/100
# 525/525 [==============================] - ETA: 0s - loss: 0.533 - 0s 207us/sample - loss: 0.5311 - val_loss: 0.5210
# Epoch 98/100
# 525/525 [==============================] - ETA: 0s - loss: 0.528 - 0s 215us/sample - loss: 0.5309 - val_loss: 0.5207
# Epoch 99/100
# 525/525 [==============================] - ETA: 0s - loss: 0.530 - 0s 213us/sample - loss: 0.5307 - val_loss: 0.5204
# Epoch 100/100
# 525/525 [==============================] - ETA: 0s - loss: 0.527 - 0s 211us/sample - loss: 0.5304 - val_loss: 0.5201

# %%
decoded_stocks = autoencoder.predict(np.array(X_val))

# %%
import pywt
def WT(index_list, wavefunc='db4', lv=4, m=1, n=4, plot=False):
    
    '''
    WT: Wavelet Transformation Function
    index_list: Input Sequence;
   
    lv: Decomposing Level；
 
    wavefunc: Function of Wavelet, 'db4' default；
    
    m, n: Level of Threshold Processing
   
    '''
   
    # Decomposing 
    coeff = pywt.wavedec(index_list,wavefunc,mode='sym',level=lv)   #  Decomposing by levels，cD is the details coefficient
    sgn = lambda x: 1 if x > 0 else -1 if x < 0 else 0 # sgn function 

    # Denoising
    # Soft Threshold Processing Method
    for i in range(m,n+1):   #  Select m~n Levels of the wavelet coefficients，and no need to dispose the cA coefficients(approximation coefficients)
        cD = coeff[i]
        Tr = np.sqrt(2*np.log2(len(cD)))  # Compute Threshold
        for j in range(len(cD)):
            if cD[j] >= Tr:
                coeff[i][j] = sgn(cD[j]) * (np.abs(cD[j]) -  Tr)  # Shrink to zero
            else:
                coeff[i][j] = 0   # Set to zero if smaller than threshold

    # Reconstructing
    coeffs = {}
    for i in range(len(coeff)):
        coeffs[i] = copy.deepcopy(coeff)
        for j in range(len(coeff)):
            if j != i:
                coeffs[i][j] = np.zeros_like(coeff[j])
    
    for i in range(len(coeff)):
        coeff[i] = pywt.waverec(coeffs[i], wavefunc)
        if len(coeff[i]) > len(index_list):
            coeff[i] = coeff[i][:-1]
            
    denoised_index = np.sum(coeff, axis=0)   
        
    if plot:     
        data.plot(figsize=(10,5))
        plt.title(f'Level_{lv}')
   
    return denoised_index

# %%
def Close_denoise(data, feature='close', levels=6, scale=True):

    d = data.copy().sort_values(by='ts').reset_index(drop=True)
    sc = MinMaxScaler(feature_range = (0, 1))
    a = sc.fit_transform(np.array(d[feature]).reshape(len(d), 1))
    d['close_normalized'] = a
    
    d['denoised'] =  WT(d['close_normalized'], lv=levels, n=levels)

    return d

# %%
df_list = [group[1] for group in data.groupby(data['StockNo'])]

output_list = []

for i, df in enumerate(tqdm(df_list, total=len(df_list))):
    output_list.append(Close_denoise(df))
    
data = pd.concat(output_list, axis=0)
data
# Out:
# HBox(children=(IntProgress(value=0, max=939), HTML(value='')))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
# C:\Users\011553\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pywt\_multilevel.py:45: UserWarning: Level value of 6 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))
#      StockName StockNo  close  high   low  open  return         total  \
# 0           台泥    1101   19.3  19.9  19.1  19.9     NaN  8.756613e+08
# 1           台泥    1101   18.7  19.6  18.4  19.4    -0.6  7.295642e+08
# 2           台泥    1101   20.0  20.0  18.9  19.0     1.3  1.200960e+09
# 3           台泥    1101   21.0  21.4  20.0  20.0     1.0  3.204683e+09
# 4           台泥    1101   21.0  21.3  20.4  21.0     0.0  1.477319e+09
# ...        ...     ...    ...   ...   ...   ...     ...           ...
# 2848       世紀鋼    9958   77.3  78.9  77.1  78.9    -0.2  2.371908e+08
# 2849       世紀鋼    9958   77.7  79.3  77.5  77.9     0.4  4.648791e+08
# 2850       世紀鋼    9958   76.3  78.4  76.2  78.4    -1.4  3.086962e+08
# 2851       世紀鋼    9958   75.8  77.0  75.8  76.6    -0.5  1.328813e+08
# 2852       世紀鋼    9958   75.8  76.5  75.4  75.8     0.0  1.161456e+08
#
#              ts          vol              On_Date  denoised  close_normalized
# 0    2004-02-11   44990547.0           1962-02-09  0.139747          0.124072
# 1    2004-02-12   38283630.0           1962-02-09  0.139777          0.111347
# 2    2004-02-13   60809947.0           1962-02-09  0.139809          0.138918
# 3    2004-02-16  154068407.0           1962-02-09  0.139842          0.160127
# 4    2004-02-17   70709589.0           1962-02-09  0.139875          0.160127
# ...         ...          ...                  ...       ...               ...
# 2848 2019-09-17    3050500.0  2008-03-12 00:00:00  0.744289          0.760801
# 2849 2019-09-18    5940537.0  2008-03-12 00:00:00  0.744535          0.765016
# 2850 2019-09-19    4011923.0  2008-03-12 00:00:00  0.744784          0.750263
# 2851 2019-09-20    1742684.0  2008-03-12 00:00:00  0.745043          0.744995
# 2852 2019-09-23    1530090.0  2008-03-12 00:00:00  0.745221          0.744995
#
# [2874553 rows x 13 columns]

# %%
def Cluster_df(data, End, Start=date(2004,2,11), feature='denoised'):
    dates = [Start + timedelta(days=x) for x in range((End-Start).days)]
    
    df = data[data.ts.isin(dates)]
    df_list = [group[1] for group in df.groupby(df['StockNo'])]

    return_list = []
    for i, d in enumerate(tqdm(df_list, total=len(df_list))):
        
        
        Stockname = d['StockName'].unique()[0]
        d = d.sort_values(by='ts').set_index('ts')

        Series = (d[feature]).rename(Stockname)
        return_list.append(Series.iloc[1:])

    Return_df = pd.concat(return_list, axis=1)

    return Return_df

# %%
df = Cluster_df(data, date(2017,9,1))
# Out:
# HBox(children=(IntProgress(value=0, max=887), HTML(value='')))

# %%
df
# Out:
#                   台泥        亞泥        嘉泥        環泥        幸福        信大  \
# ts
# 2004-02-12  0.139777  0.189640  0.486706  0.226725  0.508361  0.379795
# 2004-02-13  0.139809  0.190366  0.486454  0.226695  0.509362  0.380785
# 2004-02-16  0.139842  0.191118  0.486194  0.226662  0.510398  0.381812
# 2004-02-17  0.139875  0.191879  0.485932  0.226629  0.511446  0.382850
# 2004-02-18  0.139909  0.192655  0.485665  0.226596  0.512512  0.383907
# ...              ...       ...       ...       ...       ...       ...
# 2017-08-25  0.445936  0.247560  0.118374  0.513540  0.318950  0.335597
# 2017-08-28  0.445689  0.247420  0.119005  0.513149  0.318313  0.337151
# 2017-08-29  0.445426  0.247388  0.119686  0.513048  0.317812  0.338711
# 2017-08-30  0.445146  0.247467  0.120416  0.513244  0.317450  0.340276
# 2017-08-31  0.444859  0.247610  0.121175  0.513614  0.317161  0.341852
#
#                   東泥        味全        味王        大成  ...        宏全        信義  \
# ts                                                  ...
# 2004-02-12  0.439737  0.125313  0.343064  0.054841  ...  0.448082  0.631796
# 2004-02-13  0.439499  0.125639  0.343788  0.055001  ...  0.447909  0.632751
# 2004-02-16  0.439252  0.125977  0.344538  0.055167  ...  0.447731  0.633739
# 2004-02-17  0.439003  0.126318  0.345297  0.055334  ...  0.447551  0.634739
# 2004-02-18  0.438750  0.126666  0.346070  0.055505  ...  0.447368  0.635757
# ...              ...       ...       ...       ...  ...       ...       ...
# 2017-08-25  0.695003  0.207131  0.692554  0.568349  ...  0.525732  0.093124
# 2017-08-28  0.694082  0.207246  0.692603  0.568940  ...  0.525319  0.093407
# 2017-08-29  0.693255  0.207385  0.692702  0.569515  ...  0.525175  0.093793
# 2017-08-30  0.692524  0.207549  0.692850  0.570073  ...  0.525308  0.094286
# 2017-08-31  0.691842  0.207724  0.693024  0.570621  ...  0.525595  0.094842
#
#                   裕融        茂順       好樂迪        新麗       潤泰新      三發地產  \
# ts
# 2004-02-12  0.155889  0.170450  0.286209  0.297426  0.062478       NaN
# 2004-02-13  0.155847  0.170715  0.286548  0.296902  0.062705       NaN
# 2004-02-16  0.155803  0.170989  0.286899  0.296359  0.062942       NaN
# 2004-02-17  0.155758  0.171267  0.287254  0.295810  0.063180       NaN
# 2004-02-18  0.155713  0.171550  0.287616  0.295251  0.063424       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2017-08-25  0.831165  0.476000  0.638336  0.101017  0.412902  0.032524
# 2017-08-28  0.831428  0.476535  0.638293  0.100873  0.412239  0.031327
# 2017-08-29  0.831517  0.477121  0.638449  0.100736  0.411662  0.030264
# 2017-08-30  0.831427  0.477759  0.638808  0.100605  0.411173  0.029410
# 2017-08-31  0.831221  0.478433  0.639283  0.100479  0.410734  0.028608
#
#                   佳龍       世紀鋼
# ts
# 2004-02-12       NaN       NaN
# 2004-02-13       NaN       NaN
# 2004-02-16       NaN       NaN
# 2004-02-17       NaN       NaN
# 2004-02-18       NaN       NaN
# ...              ...       ...
# 2017-08-25  0.031407  0.050798
# 2017-08-28  0.031689  0.050345
# 2017-08-29  0.031914  0.049916
# 2017-08-30  0.032118  0.049473
# 2017-08-31  0.032283  0.049015
#
# [3360 rows x 887 columns]

# %%
def Correlation(data):
    corr = data.dropna().corr().iloc[0,1]
        
    return corr

# %%
corr_matrix = pd.DataFrame(index=df.columns, columns=df.columns)

# %%
stock_list = df.columns.tolist()
for i, stock in enumerate(tqdm(stock_list, total=len(stock_list))):
    for stock2 in stock_list[i+1:]:
        d = df[[stock, stock2]]
        corr = Correlation(d)
        corr_matrix.loc[stock, stock2], corr_matrix.loc[stock2, stock] = corr, corr
# Out:
# HBox(children=(IntProgress(value=0, max=887), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-304-a00e00b3db1a> in <module>
#       4         d = df[[stock, stock2]]
#       5         corr = Correlation(d)
# ----> 6         corr_matrix.loc[stock, stock2], corr_matrix.loc[stock2, stock] = corr, corr
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     591             # actually do the set
#     592             self.obj._consolidate_inplace()
# --> 593             self.obj._data = self.obj._data.setitem(indexer=indexer, value=value)
#     594             self.obj._maybe_update_cacher(clear=True)
#     595
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\internals\managers.py in setitem(self, **kwargs)
#     558
#     559     def setitem(self, **kwargs):
# --> 560         return self.apply("setitem", **kwargs)
#     561
#     562     def putmask(self, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\internals\blocks.py in setitem(self, indexer, value)
#     941
#     942         # coerce and try to infer the dtypes of the result
# --> 943         values = self._try_coerce_and_cast_result(values, dtype)
#     944         if transpose:
#     945             values = values.T
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\internals\blocks.py in _try_coerce_and_cast_result(self, result, dtype)
#     745     def _try_coerce_and_cast_result(self, result, dtype=None):
#     746         result = self._try_coerce_result(result)
# --> 747         result = self._try_cast_result(result, dtype=dtype)
#     748         return result
#     749
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\internals\blocks.py in _try_cast_result(self, result, dtype)
#     708
#     709         # may need to change the dtype here
# --> 710         return maybe_downcast_to_dtype(result, dtype)
#     711
#     712     def _coerce_values(self, values):
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\pandas\core\dtypes\cast.py in maybe_downcast_to_dtype(result, dtype)
#     104     if isinstance(dtype, str):
#     105         if dtype == "infer":
# --> 106             inferred_type = lib.infer_dtype(ensure_object(result.ravel()), skipna=False)
#     107             if inferred_type == "boolean":
#     108                 dtype = "bool"
#
# KeyboardInterrupt:

# %%
import scipy
scipy.stats.pearsonr(df['台泥'], df['世紀鋼'].dropna())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-296-87112d643388> in <module>
#       1 import scipy
# ----> 2 scipy.stats.pearsonr(df['台泥'], df['世紀鋼'].dropna())
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3387     n = len(x)
#    3388     if n != len(y):
# -> 3389         raise ValueError('x and y must have the same length.')
#    3390
#    3391     if n < 2:
#
# ValueError: x and y must have the same length.
