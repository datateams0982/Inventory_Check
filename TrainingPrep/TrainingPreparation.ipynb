# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime, timedelta, date
from tqdm import tqdm_notebook as tqdm

from multiprocessing import Pool
from functools import partial
import Training_function as func

# %%
data = pd.read_csv('D:\\庫存健診開發\\data\\Stock\\TWSE_Stock_feature.csv', converters={'ts': str, 'StockNo': str, 'StockName': str})
data['ts'] = pd.to_datetime(data['ts'])
data
# Out:
#         StockName StockNo      close       high        low       open  return  \
# 0              嘉泥    1103  21.296674  21.865448  20.975740  21.462088     NaN
# 1              嘉泥    1103  21.293410  21.856344  20.975407  21.458549    -0.9
# 2              嘉泥    1103  21.290035  21.846936  20.975061  21.454905     0.4
# 3              嘉泥    1103  21.286540  21.837203  20.974701  21.451152     1.0
# 4              嘉泥    1103  21.282995  21.827354  20.974325  21.447354    -0.1
# ...           ...     ...        ...        ...        ...        ...     ...
# 2870369       世紀鋼    9958  76.348356  77.628386  75.866043  76.750901    -0.2
# 2870370       世紀鋼    9958  76.066016  77.361494  75.746432  76.633749     0.4
# 2870371       世紀鋼    9958  75.951315  77.251652  75.744959  76.626244    -1.4
# 2870372       世紀鋼    9958  75.986793  77.281113  75.838004  76.705426    -0.5
# 2870373       世紀鋼    9958  76.075653  77.355967  75.965079  76.812014     0.0
#
#                total         ts           vol  ...  lower_band      skew  \
# 0        333925503.0 2004-02-11  1.540757e+07  ...         NaN       NaN
# 1        246048766.0 2004-02-12  1.261464e+07  ...         NaN       NaN
# 2        333309529.0 2004-02-13  1.389159e+07  ...         NaN       NaN
# 3        515700813.0 2004-02-16  1.544741e+07  ...         NaN       NaN
# 4        333141524.0 2004-02-17  1.429967e+07  ...         NaN       NaN
# ...              ...        ...           ...  ...         ...       ...
# 2870369  237190800.0 2019-09-17  4.322005e+06  ...   67.794944  0.157269
# 2870370  464879118.0 2019-09-18  3.066161e+06  ...   67.818320 -0.009699
# 2870371  308696223.0 2019-09-19  2.464138e+06  ...   67.956700 -0.197361
# 2870372  132881305.0 2019-09-20  2.295856e+06  ...   68.197528 -0.399103
# 2870373  116145620.0 2019-09-23  2.735556e+06  ...   68.567940 -0.618851
#
#          kurtosis   pvt_current           pvt        TR       ATR    RSI_15  \
# 0             NaN           NaN           NaN  0.889707  0.889707  0.000000
# 1             NaN  -1933.246953           NaN  0.880937  0.885030  0.000000
# 2             NaN  -2202.180939  -4135.427892  0.871875  0.880048  0.000000
# 3             NaN  -2535.341304  -4737.522243  0.862502  0.874748  0.000000
# 4             NaN  -2381.590908  -4916.932212  0.853029  0.869174  0.000000
# ...           ...           ...           ...       ...       ...       ...
# 2870369 -1.657966  -6917.656338   1074.106071  1.762344  2.053091  0.823950
# 2870370 -1.739897 -11338.824364 -18256.480703  1.615062  1.998337  0.789301
# 2870371 -1.723848  -3715.723244 -15054.547608  1.506693  1.936882  0.788834
# 2870372 -1.605250   1072.435713  -2643.287531  1.443109  1.875160  0.791651
# 2870373 -1.356955   3198.991040   4271.426753  1.390888  1.814626  0.799421
#
#             SO%k5     SO%d3
# 0        0.000000  0.000000
# 1        0.000000  0.000000
# 2        0.000000  0.000000
# 3        0.000000  0.000000
# 4        0.346383  0.178778
# ...           ...       ...
# 2870369  0.379665  0.474749
# 2870370  0.253416  0.364083
# 2870371  0.162948  0.263515
# 2870372  0.121482  0.192499
# 2870373  0.175581  0.184040
#
# [2870374 rows x 31 columns]

# %%
train_df = pd.read_csv('D:\\庫存健診開發\\data\\Clustering\\train_cluster.csv', index_col=0)
test_df = pd.read_csv('D:\\庫存健診開發\\data\\Clustering\\test_cluster.csv', index_col=0)

# %%
file_path = 'D:\\庫存健診開發\\data\\Training\\Raw\\'
func.ClusterSplit(train_df, test_df, data, file_path)
# Out:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))

# %%
data = pd.read_csv('D:\\庫存健診開發\\data\\Training\\Raw\\Cluster_0.csv', converters={'ts': str, 'StockNo': str, 'StockName': str})
data['ts'] = pd.to_datetime(data['ts'])
data
# Out:
#        StockName StockNo       close        high         low        open  \
# 0             亞泥    1102   23.869740   24.366515   23.277261   23.766541
# 1             亞泥    1102   23.900024   24.396603   23.318646   23.805446
# 2             亞泥    1102   23.931360   24.427742   23.361480   23.845723
# 3             亞泥    1102   23.963821   24.460004   23.405864   23.887465
# 4             亞泥    1102   23.996646   24.492628   23.450749   23.929679
# ...          ...     ...         ...         ...         ...         ...
# 262674        豐泰    9910  212.664249  215.452195  211.104309  212.621361
# 262675        豐泰    9910  211.094301  213.994288  210.085503  211.051012
# 262676        豐泰    9910  210.585291  213.624853  209.860156  210.550065
# 262677        豐泰    9910  211.293958  214.514407  210.545322  211.305370
# 262678        豐泰    9910  211.967225  215.326795  211.180972  211.998248
#
#         return         total         ts           vol  ...  lower_band  \
# 0          NaN  1.895267e+08 2004-02-11  1.953132e+07  ...         NaN
# 1         -0.5  2.468034e+08 2004-02-12  9.896328e+06  ...         NaN
# 2          1.4  8.446286e+08 2004-02-13  2.937028e+07  ...         NaN
# 3          0.4  1.132873e+09 2004-02-16  3.486248e+07  ...         NaN
# 4          0.8  6.549583e+08 2004-02-17  3.180797e+07  ...         NaN
# ...        ...           ...        ...           ...  ...         ...
# 262674     1.5  1.365693e+08 2019-09-17  1.587933e+06  ...  194.231677
# 262675    -2.0  4.263209e+08 2019-09-18  1.009538e+06  ...  194.420223
# 262676    -0.5  1.918511e+08 2019-09-19  9.299355e+05  ...  194.822773
# 262677    -1.0  4.088073e+08 2019-09-20  1.411221e+06  ...  195.129915
# 262678     0.5  1.974065e+08 2019-09-23  1.371041e+06  ...  195.457910
#
#             skew  kurtosis   pvt_current           pvt        TR       ATR  \
# 0            NaN       NaN           NaN           NaN  1.089254  1.089254
# 1            NaN       NaN  12555.716747           NaN  1.077957  1.083229
# 2            NaN       NaN  38508.350723  51064.067470  1.066261  1.076803
# 3            NaN       NaN  47288.042327  85796.393050  1.054141  1.069958
# 4            NaN       NaN  43568.844907  90856.887234  1.041878  1.062752
# ...          ...       ...           ...           ...       ...       ...
# 262674  0.527215 -1.144179  -4922.734473  -5698.862772  4.347886  4.092430
# 262675  0.314253 -1.366811  -7452.694728 -12375.429201  3.908786  4.069474
# 262676  0.113646 -1.459570  -2242.348658  -9695.043386  3.764697  4.031377
# 262677 -0.065605 -1.522651   4749.081522   2506.732864  3.969084  4.023591
# 262678 -0.256997 -1.485471   4368.680040   9117.761562  4.145823  4.038870
#
#           RSI_15     SO%k5     SO%d3
# 0       0.000000  0.000000  0.000000
# 1       0.000000  0.000000  0.000000
# 2       0.000000  0.000000  0.000000
# 3       0.000000  0.000000  0.000000
# 4       0.000000  0.591908  0.305501
# ...          ...       ...       ...
# 262674  0.843744  0.559036  0.653585
# 262675  0.743342  0.171682  0.412633
# 262676  0.721635  0.118849  0.265741
# 262677  0.754038  0.234999  0.250370
# 262678  0.780684  0.376798  0.313584
#
# [262679 rows x 31 columns]

# %%
train_df, test_df = func.TrainTestSplit(data, date(2017,9,1))

# %%
feature_list = ['close', 'high', 'low', 'open',
       'vol', 'VWAP', 'ma7', 'ma21', '26ema', '12ema', 'MACD', 'upper_band',
       'lower_band', 'skew', 'kurtosis', 'pvt', 'ATR',
       'RSI_15', 'SO%k5', 'SO%d3']

print(train_df[feature_list].isna().values.any())
print(test_df[feature_list].isna().values.any())
# Out:
# False
# False

# %%
param = func.GetScalerParam(train_df, feature_list)
param
# Out:
#                      max           min           std          mean
# close       5.983855e+03  1.590563e+00  2.213884e+02  8.258208e+01
# high        6.026190e+03  1.615001e+00  2.245665e+02  8.371389e+01
# low         5.931779e+03  1.562440e+00  2.186572e+02  8.156756e+01
# open        5.964244e+03  1.583817e+00  2.216126e+02  8.267925e+01
# vol         1.718654e+09 -2.427316e+08  1.936487e+07  1.442340e+07
# VWAP        5.964397e+03  0.000000e+00  2.215781e+02  8.262077e+01
# ma7         5.835268e+03  1.591341e+00  2.203592e+02  8.248618e+01
# ma21        5.629000e+03  1.596543e+00  2.180936e+02  8.226813e+01
# 26ema       5.612229e+03  1.614660e+00  2.172560e+02  8.219349e+01
# 12ema       5.736287e+03  1.596358e+00  2.195174e+02  8.240857e+01
# MACD        1.645178e+02 -1.498371e+02  5.398099e+00  2.150817e-01
# upper_band  5.976345e+03  1.606311e+00  2.309541e+02  8.598000e+01
# lower_band  5.284498e+03 -6.546928e+01  2.054908e+02  7.855627e+01
# skew        4.129428e+00 -4.113119e+00  6.044963e-01 -1.047618e-02
# kurtosis    1.505234e+01 -1.998610e+00  7.495873e-01 -8.415685e-01
# pvt         2.386969e+07 -6.238902e+06  2.711125e+05  7.966355e+03
# ATR         1.809449e+02  4.934729e-02  6.916342e+00  2.235467e+00
# RSI_15      1.000000e+00  0.000000e+00  4.106909e-01  5.305280e-01
# SO%k5       1.509499e+00 -3.124738e-01  1.841398e-01  4.944503e-01
# SO%d3       1.211839e+00 -6.731475e-02  1.765273e-01  4.943964e-01

# %%
train_df, test_df = func.Scaler(train_df, feature_list, param), func.Scaler(test_df, feature_list, param)
display(train_df)
display(test_df)
# Out:
#        StockName StockNo     close      high       low      open  return  \
# 24            亞泥    1102  0.003664  0.003715  0.003632  0.003682   -0.30
# 25            亞泥    1102  0.003654  0.003704  0.003622  0.003672   -1.30
# 26            亞泥    1102  0.003642  0.003693  0.003611  0.003662    0.80
# 27            亞泥    1102  0.003630  0.003681  0.003599  0.003650   -0.40
# 28            亞泥    1102  0.003618  0.003668  0.003588  0.003638   -1.70
# ...          ...     ...       ...       ...       ...       ...     ...
# 230306       潤泰新    9945  0.005084  0.005075  0.005078  0.005081    0.15
# 230307       潤泰新    9945  0.005079  0.005070  0.005074  0.005078    0.30
# 230308       潤泰新    9945  0.005076  0.005066  0.005070  0.005074   -0.20
# 230309       潤泰新    9945  0.005072  0.005063  0.005066  0.005069    0.25
# 230310       潤泰新    9945  0.005070  0.005060  0.005062  0.005064   -4.30
#
#               total         ts       vol  ...  lower_band      skew  kurtosis  \
# 24      310866303.0 2004-03-16  0.133052  ...    0.016638  0.394791  0.083439
# 25      346863303.0 2004-03-17  0.127142  ...    0.016624  0.407277  0.073030
# 26      289156687.0 2004-03-18  0.129164  ...    0.016610  0.417999  0.065862
# 27      143443290.0 2004-03-19  0.130670  ...    0.016595  0.426842  0.061068
# 28        5433306.0 2004-03-22  0.130375  ...    0.016580  0.434230  0.057606
# ...             ...        ...       ...  ...         ...       ...       ...
# 230306   87563089.0 2017-08-25  0.127080  ...    0.018203  0.536452  0.056048
# 230307  221046845.0 2017-08-28  0.127034  ...    0.018199  0.532739  0.056082
# 230308  147117920.0 2017-08-29  0.127817  ...    0.018196  0.528884  0.055443
# 230309  341438107.0 2017-08-30  0.129561  ...    0.018192  0.526144  0.054457
# 230310  422712010.0 2017-08-31  0.131666  ...    0.018189  0.524464  0.052877
#
#          pvt_current       pvt        TR       ATR        RSI_15     SO%k5  \
# 24     -47902.399949  0.204056  0.895503  0.004873  4.564914e-02  0.371058
# 25     -18024.293974  0.205024  0.890688  0.004845  3.726107e-02  0.368976
# 26     -30615.535921  0.205598  0.886101  0.004817  3.043117e-02  0.366378
# 27     -41708.513761  0.204811  0.881781  0.004789  2.485731e-02  0.363099
# 28     -41133.705304  0.204462  0.877431  0.004762  2.046054e-02  0.360048
# ...              ...       ...       ...       ...           ...       ...
# 230306  -5460.719778  0.206865  0.510668  0.002562  1.626348e-08  0.459860
# 230307  -5451.077578  0.206851  0.506902  0.002558  1.472414e-08  0.459724
# 230308  -5752.154605  0.206841  0.507053  0.002555  1.329783e-08  0.462422
# 230309  -6771.974988  0.206797  0.511514  0.002555  1.196517e-08  0.468068
# 230310  -8094.438747  0.206720  0.518187  0.002559  1.074345e-08  0.476250
#
#            SO%d3
# 24      0.341643
# 25      0.337770
# 26      0.333983
# 27      0.329755
# 28      0.325467
# ...          ...
# 230306  0.463679
# 230307  0.463417
# 230308  0.465207
# 230309  0.470123
# 230310  0.478408
#
# [228559 rows x 31 columns]
#        StockName StockNo     close      high       low      open  return  \
# 230311        亞泥    1102  0.004309  0.004293  0.004321  0.004322    0.10
# 230312        亞泥    1102  0.004306  0.004289  0.004317  0.004318    0.00
# 230313        亞泥    1102  0.004303  0.004285  0.004314  0.004314    0.00
# 230314        亞泥    1102  0.004301  0.004282  0.004310  0.004310   -0.25
# 230315        亞泥    1102  0.004297  0.004277  0.004306  0.004305   -0.10
# ...          ...     ...       ...       ...       ...       ...     ...
# 262674        豐泰    9910  0.035283  0.035494  0.035335  0.035393    1.50
# 262675        豐泰    9910  0.035021  0.035252  0.035163  0.035130   -2.00
# 262676        豐泰    9910  0.034936  0.035191  0.035125  0.035046   -0.50
# 262677        豐泰    9910  0.035054  0.035338  0.035240  0.035172   -1.00
# 262678        豐泰    9910  0.035167  0.035473  0.035348  0.035289    0.50
#
#               total         ts       vol  ...  lower_band      skew  kurtosis  \
# 230311   94790172.0 2017-09-01  0.125536  ...    0.017117  0.930446  0.827289
# 230312   46852247.0 2017-09-04  0.124695  ...    0.017100  0.794944  0.375853
# 230313  100375245.0 2017-09-05  0.125640  ...    0.017091  0.721068  0.210036
# 230314   88723794.0 2017-09-06  0.125280  ...    0.017087  0.670791  0.125799
# 230315   73188947.0 2017-09-07  0.125237  ...    0.017087  0.632440  0.076370
# ...             ...        ...       ...  ...         ...       ...       ...
# 262674  136569295.0 2019-09-17  0.124565  ...    0.048543  0.562973  0.050110
# 262675  426320900.0 2019-09-18  0.124270  ...    0.048578  0.537136  0.037054
# 262676  191851142.0 2019-09-19  0.124229  ...    0.048653  0.512798  0.031614
# 262677  408807276.0 2019-09-20  0.124475  ...    0.048710  0.491051  0.027914
# 262678  197406460.0 2019-09-23  0.124454  ...    0.048772  0.467831  0.030094
#
#           pvt_current       pvt        TR       ATR    RSI_15     SO%k5  \
# 230311  100131.207017  0.210688  0.873443  0.001731  0.968014  0.668619
# 230312   -1123.134367  0.210502  0.289917  0.001681  0.944271  0.660374
# 230313   -2153.200537  0.207104  0.288386  0.001636  0.918182  0.651841
# 230314   -1614.047005  0.207088  0.287165  0.001596  0.890237  0.643318
# 230315   -2318.861314  0.207083  0.285138  0.001559  0.849463  0.461555
# ...               ...       ...       ...       ...       ...       ...
# 262674   -4922.734473  0.207024  4.347886  0.022350  0.843744  0.478333
# 262675   -7452.694728  0.206802  3.908786  0.022223  0.743342  0.265732
# 262676   -2242.348658  0.206891  3.764697  0.022013  0.721635  0.236734
# 262677    4749.081522  0.207297  3.969084  0.021970  0.754038  0.300483
# 262678    4368.680040  0.207516  4.145823  0.022054  0.780684  0.378311
#
#            SO%d3
# 230311  0.734614
# 230312  0.741783
# 230313  0.739290
# 230314  0.731974
# 230315  0.598868
# ...          ...
# 262674  0.563575
# 262675  0.375207
# 262676  0.260372
# 262677  0.248355
# 262678  0.297774
#
# [32320 rows x 31 columns]

# %%
df_list = [group[1] for group in train_df.groupby(train_df['StockNo'])]

X_train, Y_train = [], []

if __name__ == '__main__':
    with Pool(processes=12) as pool:
        for i, x in enumerate(tqdm(pool.imap_unordered(partial(func.separate_elimination, lookback=20, forward=5, feature_list=feature_list), df_list), total=len(df_list)), 1):
            for xx in x[0]:
                X_train.append(xx.tolist())
            Y_train.extend(x[1])

np.array(X_train).shape
# Out:
# HBox(children=(IntProgress(value=0, max=73), HTML(value='')))
# (226459, 20, 20)

# %%
df_list = [group[1] for group in test_df.groupby(test_df['StockNo'])]

X_test, Y_test = [], []

if __name__ == '__main__':
    with Pool(processes=12) as pool:
        for i, x in enumerate(tqdm(pool.imap_unordered(partial(func.create_dataset, lookback=20, forward=5, feature_list=feature_list, problem='classification'), df_list), total=len(df_list)), 1):
            for xx in x[0]:
                X_test.append(xx.tolist())
            Y_test.extend(x[1])

np.array(X_test).shape
# Out:
# HBox(children=(IntProgress(value=0, max=65), HTML(value='')))
# (30695, 20, 20)

# %%
(len(X_train) == len(Y_train)) and (len(X_test) == len(Y_test))
# Out:
# True

# %%
save_list = [X_train, Y_train,  X_test, Y_test]

# %%
cluster = 0
import pickle
with open(f'D:\\庫存健診開發\\data\\Training\\processed\\Cluster_{cluster}_classification_minmax0_Weekly', 'wb') as fp:
    pickle.dump(save_list, fp)
