# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime, timedelta, date
from tqdm import tqdm_notebook as tqdm
import seaborn as sns

from multiprocessing import Pool
from functools import partial
import Training_function as func

# %%
data = pd.read_csv('D:\\庫存健診開發\\data\\Stock\\TWSE_Stock_feature_log.csv', converters={'ts': str, 'StockNo': str, 'StockName': str})
data['ts'] = pd.to_datetime(data['ts'])
data
# Out:
#         StockName StockNo     close      high       low      open  return  \
# 0              嘉泥    1103  3.054602  3.081172  3.039477  3.062498     NaN
# 1              嘉泥    1103  3.054331  3.080633  3.039346  3.062220   -0.90
# 2              嘉泥    1103  3.054052  3.080077  3.039213  3.061934    0.40
# 3              嘉泥    1103  3.053765  3.079502  3.039076  3.061640    1.00
# 4              嘉泥    1103  3.053474  3.078921  3.038938  3.061342   -0.10
# ...           ...     ...       ...       ...       ...       ...     ...
# 2870369        佳龍    9955  2.967179  2.979450  2.960362  2.972033   -0.20
# 2870370        佳龍    9955  2.959344  2.968882  2.951687  2.961290   -0.15
# 2870371        佳龍    9955  2.953398  2.961098  2.945143  2.953369   -0.35
# 2870372        佳龍    9955  2.949554  2.956317  2.940942  2.948448    0.35
# 2870373        佳龍    9955  2.946840  2.953072  2.938003  2.945145    0.15
#
#                total         ts        vol  ...  lower_band      skew  \
# 0        333925503.0 2004-02-11  16.352479  ...         NaN       NaN
# 1        246048766.0 2004-02-12  16.340381  ...         NaN       NaN
# 2        333309529.0 2004-02-13  16.327849  ...         NaN       NaN
# 3        515700813.0 2004-02-16  16.314851  ...         NaN       NaN
# 4        333141524.0 2004-02-17  16.301702  ...         NaN       NaN
# ...              ...        ...        ...  ...         ...       ...
# 2870369   10570940.0 2019-09-17  13.502837  ...    2.967962 -0.558865
# 2870370    8499084.0 2019-09-18  13.339974  ...    2.959696 -0.520054
# 2870371   18002738.0 2019-09-19  13.222699  ...    2.951673 -0.477384
# 2870372   10280286.0 2019-09-20  13.152947  ...    2.944156 -0.405219
# 2870373    8065152.0 2019-09-23  13.105957  ...    2.937476 -0.313513
#
#          kurtosis  pvt_current       pvt        TR       ATR    RSI_15  \
# 0             NaN          NaN       NaN  0.041694  0.041694  0.000000
# 1             NaN    -0.001451       NaN  0.041286  0.041477  0.000000
# 2             NaN    -0.001491 -0.002942  0.040864  0.041245  0.000000
# 3             NaN    -0.001533 -0.003024  0.040426  0.040997  0.000000
# 4             NaN    -0.001550 -0.003083  0.039983  0.040737  0.000000
# ...           ...          ...       ...       ...       ...       ...
# 2870369 -0.907656    -0.034107 -0.066696  0.019089  0.024738  0.059349
# 2870370 -0.949418    -0.035223 -0.069330  0.017195  0.023795  0.048550
# 2870371 -1.036020    -0.026570 -0.061794  0.015955  0.022815  0.041966
# 2870372 -1.162565    -0.017119 -0.043690  0.015375  0.021885  0.038169
# 2870373 -1.292763    -0.012058 -0.029178  0.015069  0.021033  0.035594
#
#             SO%k5     SO%d3
# 0        0.000000  0.000000
# 1        0.000000  0.000000
# 2        0.000000  0.000000
# 3        0.000000  0.000000
# 4        0.344183  0.177643
# ...           ...       ...
# 2870369  0.124392  0.117789
# 2870370  0.139673  0.128731
# 2870371  0.156701  0.142716
# 2870372  0.178432  0.160574
# 2870373  0.213208  0.186891
#
# [2870374 rows x 31 columns]

# %%
train_df = pd.read_csv('D:\\庫存健診開發\\data\\Clustering\\train_cluster.csv', index_col=0)
test_df = pd.read_csv('D:\\庫存健診開發\\data\\Clustering\\test_cluster.csv', index_col=0)

# %%
file_path = 'D:\\庫存健診開發\\data\\Training\\Raw\\log\\'
func.ClusterSplit(train_df, test_df, data, file_path)
# Out:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))

# %%
cluster = 8

# %%
data = pd.read_csv(f'D:\\庫存健診開發\\data\\Training\\Raw\\Cluster_{cluster}.csv', converters={'ts': str, 'StockNo': str, 'StockName': str})
data['ts'] = pd.to_datetime(data['ts'])
data
# Out:
#        StockName StockNo     close      high       low      open  return  \
# 0             宏洲    1413  5.887760  6.098818  5.813922  5.973626     NaN
# 1             宏洲    1413  5.873535  6.081861  5.799649  5.957226   -0.45
# 2             宏洲    1413  5.858792  6.064287  5.784857  5.940231    0.00
# 3             宏洲    1413  5.843494  6.046054  5.769510  5.922598   -0.05
# 4             宏洲    1413  5.828023  6.027612  5.753988  5.904764    0.05
# ...          ...     ...       ...       ...       ...       ...     ...
# 191663        中視    9928  4.728964  4.851535  4.633840  4.670024   -0.13
# 191664        中視    9928  4.778759  4.918808  4.687598  4.720119    0.00
# 191665        中視    9928  4.814456  4.967952  4.724157  4.754486    0.09
# 191666        中視    9928  4.834899  4.997025  4.742722  4.772090    0.00
# 191667        中視    9928  4.849179  5.018347  4.754046  4.783123    0.12
#
#              total         ts           vol  ...  lower_band      skew  \
# 0       63494481.0 2004-02-11  7.829951e+06  ...         NaN       NaN
# 1       32909123.0 2004-02-12  3.906600e+06  ...         NaN       NaN
# 2       32928151.0 2004-02-13  4.827844e+06  ...         NaN       NaN
# 3       18572256.0 2004-02-16  3.629163e+06  ...         NaN       NaN
# 4       26696158.0 2004-02-17  4.589334e+06  ...         NaN       NaN
# ...            ...        ...           ...  ...         ...       ...
# 191663    295881.0 2019-09-17 -5.823117e+04  ...    4.520500  1.382684
# 191664    217022.0 2019-09-18  4.976759e+03  ...    4.498549  1.566126
# 191665     12005.0 2019-09-19  4.031298e+04  ...    4.477590  1.452020
# 191666     29049.0 2019-09-20  4.681084e+04  ...    4.461113  1.233307
# 191667     74009.0 2019-09-23  7.659410e+04  ...    4.449052  1.007900
#
#         kurtosis   pvt_current           pvt        TR       ATR    RSI_15  \
# 0            NaN           NaN           NaN  0.284896  0.284896  0.000000
# 1            NaN  -9438.596797           NaN  0.282212  0.283464  0.000000
# 2            NaN -12118.226650 -21556.823448  0.279430  0.281936  0.000000
# 3            NaN  -9475.744777 -21593.971428  0.276544  0.280307  0.000000
# 4            NaN -12151.040323 -21626.785100  0.273624  0.278592  0.000000
# ...          ...           ...           ...       ...       ...       ...
# 191663  1.821849   -530.404968  -1040.069227  0.217695  0.132942  0.781536
# 191664  1.846374     52.403757   -478.001211  0.231209  0.145226  0.833562
# 191665  1.061860    301.140063    353.543820  0.243794  0.157547  0.861165
# 191666  0.195663    198.762547    499.902610  0.254303  0.169641  0.875163
# 191667 -0.474944    226.224080    424.986627  0.264301  0.181474  0.884890
#
#            SO%k5     SO%d3
# 0       0.000000  0.000000
# 1       0.000000  0.000000
# 2       0.000000  0.000000
# 3       0.000000  0.000000
# 4       0.214699  0.110812
# ...          ...       ...
# 191663  0.655234  0.653190
# 191664  0.642089  0.647639
# 191665  0.624603  0.636121
# 191666  0.601758  0.618940
# 191667  0.560039  0.589489
#
# [191668 rows x 31 columns]

# %%
train_df, val_df, test_df = func.TrainTestSplit(data, date(2016,1,1), date(2017,9,1))

# %%
feature_list = ['close', 'high', 'low', 'open',
       'vol', 'VWAP', 'ma7', 'ma21', '26ema', '12ema', 'MACD', 'upper_band',
       'lower_band', 'skew', 'kurtosis', 'pvt', 'ATR',
       'RSI_15', 'SO%k5', 'SO%d3']

print(train_df[feature_list].isna().values.any())
print(val_df[feature_list].isna().values.any())
print(test_df[feature_list].isna().values.any())
# Out:
# False
# False
# False

# %%
param = func.GetScalerParam(train_df, feature_list)
param
# Out:
#                      max           min           std           mean
# close       1.404275e+02  0.000000e+00  1.021345e+01      10.163894
# high        1.446129e+02  0.000000e+00  1.040268e+01      10.347482
# low         1.377094e+02  0.000000e+00  1.005421e+01      10.000087
# open        1.425675e+02  0.000000e+00  1.022719e+01      10.170727
# vol         5.296515e+07 -9.540761e+06  2.094979e+06  924585.041668
# VWAP        1.416709e+02 -1.314271e-02  1.020258e+01       9.912436
# ma7         1.367776e+02 -1.946367e-01  1.023497e+01      10.176657
# ma21        1.362769e+02 -1.694091e-02  1.027573e+01      10.206449
# 26ema       1.343863e+02  1.807049e-01  1.025832e+01      10.216288
# 12ema       1.366690e+02 -6.526813e-02  1.024017e+01      10.187273
# MACD        1.764847e+01 -1.013626e+01  5.590732e-01      -0.029015
# upper_band  1.427646e+02  2.995568e-01  1.103300e+01      10.771152
# lower_band  1.322908e+02 -2.021664e+01  9.627610e+00       9.641746
# skew        4.129346e+00 -4.124702e+00  5.864989e-01       0.015132
# kurtosis    1.505192e+01 -1.999683e+00  7.072787e-01      -0.887157
# pvt         4.741739e+06 -1.940665e+06  4.911079e+04    1112.121676
# ATR         1.006895e+01  2.399584e-03  4.214794e-01       0.355954
# RSI_15      1.000000e+00  0.000000e+00  4.368937e-01       0.447474
# SO%k5       1.076521e+02 -2.178454e+02  6.860999e-01       0.470662
# SO%d3       5.356260e+01 -1.101962e+02  4.300335e-01       0.470613

# %%
train_df, val_df, test_df = func.Scaler(train_df, feature_list, param), func.Scaler(val_df, feature_list, param), func.Scaler(test_df, feature_list, param)
display(train_df)
display(test_df)
# Out:
#        StockName StockNo     close      high       low      open  return  \
# 24            宏洲    1413  0.038852  0.038826  0.039085  0.038603   -0.15
# 25            宏洲    1413  0.038697  0.038664  0.038928  0.038443   -0.15
# 26            宏洲    1413  0.038540  0.038499  0.038768  0.038281    0.10
# 27            宏洲    1413  0.038381  0.038333  0.038606  0.038117   -0.20
# 28            宏洲    1413  0.038219  0.038165  0.038442  0.037951   -0.35
# ...          ...     ...       ...       ...       ...       ...     ...
# 170680        中視    9928  0.071528  0.070329  0.072049  0.070460    0.14
# 170681        中視    9928  0.071268  0.070071  0.071796  0.070207   -0.10
# 170682        中視    9928  0.070991  0.069796  0.071527  0.069937    0.00
# 170683        中視    9928  0.070710  0.069516  0.071253  0.069663    0.10
# 170684        中視    9928  0.070416  0.069224  0.070968  0.069378   -0.17
#
#             total         ts       vol  ...  lower_band      skew  kurtosis  \
# 24      9747490.0 2004-03-16  0.211048  ...    0.168166  0.485437  0.047303
# 25      8130133.0 2004-03-17  0.176650  ...    0.168019  0.485671  0.047143
# 26      8670747.0 2004-03-18  0.190549  ...    0.167869  0.485969  0.046997
# 27      9363777.0 2004-03-19  0.192839  ...    0.167718  0.486292  0.046880
# 28       306000.0 2004-03-22  0.190859  ...    0.167565  0.486655  0.046796
# ...           ...        ...       ...  ...         ...       ...       ...
# 170680   190914.0 2015-12-25  0.153579  ...    0.197819  0.488522  0.035284
# 170681   287603.0 2015-12-28  0.153781  ...    0.197526  0.497789  0.035868
# 170682   262564.0 2015-12-29  0.153872  ...    0.197245  0.506077  0.037991
# 170683   243288.0 2015-12-30  0.153899  ...    0.196979  0.512890  0.041182
# 170684   135751.0 2015-12-31  0.153771  ...    0.196729  0.517386  0.044754
#
#          pvt_current       pvt        TR       ATR    RSI_15     SO%k5  \
# 24     -14331.223754  0.286040  0.232266  0.023942  0.000000  0.669968
# 25      -5980.924712  0.287375  0.230503  0.023777  0.000000  0.669969
# 26      -9627.442909  0.288078  0.228765  0.023611  0.000000  0.669969
# 27     -10409.320140  0.287416  0.227060  0.023446  0.000000  0.669970
# 28     -10055.918893  0.287352  0.225320  0.023279  0.000000  0.669970
# ...              ...       ...       ...       ...       ...       ...
# 170680   -197.581836  0.290349  0.248762  0.026022  0.010544  0.670208
# 170681   -259.953827  0.290346  0.246220  0.025797  0.009308  0.670206
# 170682   -300.235103  0.290330  0.243486  0.025566  0.008142  0.670202
# 170683   -312.210572  0.290323  0.240667  0.025329  0.007112  0.670187
# 170684   -294.061243  0.290324  0.237701  0.025084  0.006178  0.670161
#
#            SO%d3
# 24      0.674306
# 25      0.674307
# 26      0.674308
# 27      0.674309
# 28      0.674310
# ...          ...
# 170680  0.674773
# 170681  0.674777
# 170682  0.674774
# 170683  0.674758
# 170684  0.674724
#
# [146643 rows x 31 columns]
#        StockName StockNo     close      high       low      open  return  \
# 171082        東華    1418  0.036202  0.035173  0.036353  0.035133    0.07
# 171083        東華    1418  0.036077  0.035066  0.036228  0.035027    0.07
# 171084        東華    1418  0.035940  0.034947  0.036080  0.034899   -0.01
# 171085        東華    1418  0.035790  0.034817  0.035909  0.034749    0.16
# 171086        東華    1418  0.035604  0.034656  0.035707  0.034574    0.00
# ...          ...     ...       ...       ...       ...       ...     ...
# 191663        中視    9928  0.033675  0.033548  0.033649  0.032757   -0.13
# 191664        中視    9928  0.034030  0.034014  0.034040  0.033108    0.00
# 191665        中視    9928  0.034284  0.034353  0.034305  0.033349    0.09
# 191666        中視    9928  0.034430  0.034554  0.034440  0.033472    0.00
# 191667        中視    9928  0.034532  0.034702  0.034522  0.033550    0.12
#
#            total         ts       vol  ...  lower_band      skew  kurtosis  \
# 171082   19980.0 2017-09-01  0.152794  ...    0.165942  0.478973  0.059800
# 171083   26875.0 2017-09-04  0.152698  ...    0.165715  0.471711  0.062121
# 171084   99179.0 2017-09-05  0.152941  ...    0.165502  0.470094  0.059219
# 171085    7635.0 2017-09-06  0.152727  ...    0.165300  0.471518  0.054549
# 171086    2411.0 2017-09-07  0.152694  ...    0.165100  0.473881  0.050087
# ...          ...        ...       ...  ...         ...       ...       ...
# 191663  295881.0 2019-09-17  0.151706  ...    0.162203  0.667235  0.224116
# 191664  217022.0 2019-09-18  0.152717  ...    0.162059  0.689459  0.225554
# 191665   12005.0 2019-09-19  0.153283  ...    0.161922  0.675635  0.179546
# 191666   29049.0 2019-09-20  0.153387  ...    0.161813  0.649137  0.128747
# 191667   74009.0 2019-09-23  0.153863  ...    0.161734  0.621829  0.089419
#
#         pvt_current       pvt        TR       ATR        RSI_15     SO%k5  \
# 171082  -162.956968  0.290380  0.163570  0.023453  2.328579e-07  0.669934
# 171083   -12.938058  0.290388  0.094808  0.021669  2.105501e-07  0.669935
# 171084   -72.371116  0.290401  0.097752  0.020144  1.863963e-07  0.669941
# 171085   -23.228628  0.290400  0.101956  0.018862  1.619020e-07  0.669954
# 171086   -18.138066  0.290408  0.108696  0.017825  1.375057e-07  0.670770
# ...             ...       ...       ...       ...           ...       ...
# 191663  -530.404968  0.290259  0.217695  0.012968  7.815365e-01  0.671282
# 191664    52.403757  0.290343  0.231209  0.014188  8.335618e-01  0.671242
# 191665   301.140063  0.290467  0.243794  0.015412  8.611648e-01  0.671188
# 191666   198.762547  0.290489  0.254303  0.016614  8.751629e-01  0.671118
# 191667   226.224080  0.290478  0.264301  0.017789  8.848903e-01  0.670990
#
#            SO%d3
# 171082  0.674770
# 171083  0.674506
# 171084  0.674379
# 171085  0.674329
# 171086  0.675115
# ...          ...
# 191663  0.676906
# 191664  0.676873
# 191665  0.676802
# 191666  0.676697
# 191667  0.676517
#
# [20562 rows x 31 columns]

# %%
df_list = [group[1] for group in train_df.groupby(train_df['StockNo'])]

X_train, Y_train = [], []

if __name__ == '__main__':
    with Pool(processes=12) as pool:
        for i, x in enumerate(tqdm(pool.imap_unordered(partial(func.separate_elimination, lookback=20, forward=5, feature_list=feature_list), df_list), total=len(df_list)), 1):
            for xx in x[0]:
                X_train.append(xx.tolist())
            Y_train.extend(x[1])

np.array(X_train).shape
# Out:
# HBox(children=(IntProgress(value=0, max=57), HTML(value='')))
# (144384, 20, 20)

# %%
df_list = [group[1] for group in val_df.groupby(val_df['StockNo'])]

X_val, Y_val = [], []

if __name__ == '__main__':
    with Pool(processes=12) as pool:
        for i, x in enumerate(tqdm(pool.imap_unordered(partial(func.separate_elimination, lookback=20, forward=5, feature_list=feature_list), df_list), total=len(df_list)), 1):
            for xx in x[0]:
                X_val.append(xx.tolist())
            Y_val.extend(x[1])

np.array(X_val).shape
# Out:
# HBox(children=(IntProgress(value=0, max=57), HTML(value='')))
# (21458, 20, 20)

# %%
df_list = [group[1] for group in test_df.groupby(test_df['StockNo'])]

X_test, Y_test = [], []

if __name__ == '__main__':
    with Pool(processes=12) as pool:
        for i, x in enumerate(tqdm(pool.imap_unordered(partial(func.create_dataset, lookback=20, forward=5, feature_list=feature_list, problem='classification'), df_list), total=len(df_list)), 1):
            for xx in x[0]:
                X_test.append(xx.tolist())
            Y_test.extend(x[1])

np.array(X_test).shape
# Out:
# HBox(children=(IntProgress(value=0, max=41), HTML(value='')))
# (19537, 20, 20)

# %%
(len(X_train) == len(Y_train)) and (len(X_val) == len(Y_val)) and (len(X_test) == len(Y_test))
# Out:
# True

# %%
save_list = [X_train, Y_train, X_val, Y_val, X_test, Y_test]

# %%
import pickle
with open(f'D:\\庫存健診開發\\data\\Training\\processed\\Cluster_{cluster}_classification_minmax0_Weekly', 'wb') as fp:
    pickle.dump(save_list, fp)

# %%
(not 1 == 1) or (not 2 == 3)
# Out:
# True
