# %%
import numpy as np 
import pandas as pd 
import datetime
from datetime import datetime, date
from tqdm import tqdm_notebook as tqdm
import time

from multiprocessing import Pool
from functools import partial
import VWAP_feature_function as func

# %%
data = pd.read_csv('D:\\庫存健診開發\\data\\processed\\TWSE_stock_processed_unfixed.csv', converters={'ts': str, 'StockName': str, 'StockNo': str})
data['ts'] = pd.to_datetime(data['ts'])
data
# Out:
#                 ts StockNo StockName  open   high    low  close  return  \
# 0       2007-07-02    1101        台泥  38.2  38.20  37.00  37.50   -1.57
# 1       2007-07-03    1101        台泥  37.7  37.80  37.05  37.40   -0.27
# 2       2007-07-04    1101        台泥  37.5  38.40  37.35  37.70    0.80
# 3       2007-07-05    1101        台泥  37.7  38.00  37.00  37.00   -1.86
# 4       2007-07-06    1101        台泥  37.0  38.65  36.75  38.55    4.19
# ...            ...     ...       ...   ...    ...    ...    ...     ...
# 2369242 2019-09-17    9958       世紀鋼  78.9  78.90  77.10  77.30   -0.26
# 2369243 2019-09-18    9958       世紀鋼  77.9  79.30  77.50  77.70    0.91
# 2369244 2019-09-19    9958       世紀鋼  78.4  78.40  76.20  76.30   -1.80
# 2369245 2019-09-20    9958       世紀鋼  76.6  77.00  75.80  75.80   -0.66
# 2369246 2019-09-23    9958       世紀鋼  75.8  76.50  75.40  75.80    0.00
#
#          volatility      vol  ...  industry_close  industry_return  \
# 0              3.15  10222.0  ...          124.56             0.02
# 1              2.00   9831.0  ...          124.54            -0.02
# 2              2.81  11124.0  ...          125.13             0.47
# 3              2.65  15043.0  ...          123.23            -1.52
# 4              5.14  25513.0  ...          125.67             1.98
# ...             ...      ...  ...             ...              ...
# 2369242        2.32   3050.0  ...          101.55            -1.14
# 2369243        2.34   5940.0  ...          101.80             0.25
# 2369244        2.83   4011.0  ...          101.59            -0.21
# 2369245        1.57   1742.0  ...          102.10             0.50
# 2369246        1.45   1530.0  ...          101.19            -0.89
#
#          industry_vol  foreign_buy  investment_buy dealer_buy  foreign_ratio  \
# 0             44467.0      -3917.0          -765.0      158.0          47.42
# 1             76827.0      -1035.0             0.0     1255.0          47.39
# 2             48887.0       1057.0           680.0      198.0          47.43
# 3             55899.0      -8619.0           601.0       74.0          47.16
# 4            103863.0       5288.0          1485.0     1155.0          47.32
# ...               ...          ...             ...        ...            ...
# 2369242       31349.0        508.0             0.0     -358.0           2.22
# 2369243       33530.0       -291.0             0.0      144.0           2.06
# 2369244       22747.0         64.0             0.0     -161.0           2.08
# 2369245       55930.0        144.0             0.0       21.0           2.60
# 2369246       27986.0        110.0             0.0     -114.0           2.68
#
#          investment_ratio  dealer_ratio  corporation_ratio
# 0                    0.78          0.28              48.48
# 1                    0.78          0.32              48.49
# 2                    0.80          0.32              48.55
# 3                    0.82          0.33              48.31
# 4                    0.87          0.36              48.55
# ...                   ...           ...                ...
# 2369242              1.30          1.45               4.97
# 2369243              1.30          1.52               4.88
# 2369244              1.30          1.44               4.82
# 2369245              1.30          1.45               5.35
# 2369246              1.30          1.40               5.38
#
# [2369247 rows x 35 columns]

# %%
columns_dict = {'lag': ['index_close', 'industry_close', 'close', 'VWAP', 'VWAP_day5'],
               'return': ['index', 'industry', 'close', 'VWAP', 'VWAP_day5'],
               'ratio': ['index_close', 'index_vol', 'index_return', 'industry_close', 'industry_vol', 'industry_return', 'VWAP_return', 'return', 'vol', 'VWAP', 'VWAP_day5', 'VWAP_day5_return'],
               'momentum': ['index_close', 'index_vol', 'index_return', 'industry_close', 'industry_vol', 'industry_return', 'VWAP_return', 'return', 'vol', 'VWAP', 'VWAP_day5', 'VWAP_day5_return'],
                'moment': ['index_close', 'index_vol', 'industry_close', 'industry_vol', 'vol', 'VWAP', 'VWAP_day5', 'VWAP_day5_return'],
                'buyer': ['foreign_buy', 'investment_buy', 'dealer_buy']
               }

# %%
df_list = [group[1] for group in data.groupby(data['StockNo'])]
output_list = []

if __name__ == '__main__':
    with Pool(processes=12) as pool:
        for i, x in enumerate(tqdm(pool.imap_unordered(partial(func.separate_engineering, columns_dict=columns_dict), df_list), total=len(df_list)), 1):
            output_list.append(x)
                
df = pd.concat(output_list, axis=0)
df
# Out:
# HBox(children=(IntProgress(value=0, max=935), HTML(value='')))

# %%
# d = df[df['MACD_diff'].notnull()]
d = d[d['Y'].notnull()]
d = d.fillna(0)

# %%
d.to_csv('D:\\庫存健診開發\\data\\Training\\Raw\\Whole_new_large.csv', index=False)

# %%
d.to_csv('D:\\庫存健診開發\\data\\processed\\TWSE_feature_all_new.csv', index=False)

# %%
'average_volatility' in df.columns
# Out:
# False
