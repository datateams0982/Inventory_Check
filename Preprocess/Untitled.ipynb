# %%
import requests
import os
import json
import codecs
import pandas as pd
from datetime import date, timedelta, datetime
import time
from retrying import retry
import random

# %%
file_path = 'D:\\庫存健診開發\\data\\上市櫃公司基本資料\\'
file_list = os.listdir(file_path)
df_list = []

if __name__ == '__main__':
    with Pool(processes=12) as pool:
        for i, x in enumerate(tqdm(pool.imap_unordered(partial(func.read_inventory, file_path=file_path), file_list), total=len(file_list)), 1):
                df_list.append(x)
                
inventory = pd.concat(df_list, axis=0)
inventory = inventory.sort_values(by='year')
inventory

# %%
file_path = 'C:\\Users\\011553\\Downloads\\'
filename = '20040211_日法人持股估計.txt'
read_inventory(filename, file_path)
# Out:
#               ts StockNo StockName  foreign_buy  investment_buy  self_buy  \
# 0     2004-02-11    0001        鴻運          0.0             0.0         0
# 1     2004-02-11    0015        富邦          0.0             0.0         0
# 2     2004-02-11    0029       富邦店          0.0             0.0         0
# 3     2004-02-11    0050      台灣50       2641.0          -100.0       952
# 4     2004-02-11    1101        台泥        200.0          1230.0     -1600
# ...          ...     ...       ...          ...             ...       ...
# 1175  2004-02-11   TWB27       觀光類       -156.0             0.0      -107
# 1176  2004-02-11   TWB28      金融保險     -54844.0         22472.0     10926
# 1177  2004-02-11   TWB29       百貨類       8734.0          1671.0       -25
# 1178  2004-02-11   TWB99       其他類       1482.0          -143.0      2306
# 1179  2004-02-11   TWC00     OTC指數     -35249.0         -6399.0     -3543
#
#       foreign_hold  investment_hold  self_hold
# ...

# %%
data_date = str(date(2019,10,23))
file_name = 'test_{datadate}.csv'.format(datadate=data_date)
complete_file_path = 'D:\\庫存健診開發\\Stock_Crawl\\'+file_name

if download_twse_csv(download_path=complete_file_path,data_date=data_date):
    print("File: {file_name} download complete, transforming file.".format(file_name=complete_file_path))

else:
    print("File: {file_name} is empty, removing file.".format(file_name=complete_file_path))
# Out:
# File: D:\庫存健診開發\Stock_Crawl\test_2019-10-23.csv download complete, transforming file.

# %%
d = pd.read_csv(f'D:\\庫存健診開發\\Stock_Crawl\\test_{data_date}.csv')

# %%
d
# Out:
#         IndexName      Index
# 0        寶島股價報酬指數  16,118.87
# 1     發行量加權股價報酬指數  20,920.95
# 2   臺灣公司治理100報酬指數   7,833.28
# 3        臺灣50報酬指數  16,162.53
# 4     臺灣中型100報酬指數  14,524.25
# 5      臺灣資訊科技報酬指數  21,372.07
# 6        臺灣發達報酬指數  14,094.79
# 7       臺灣高股息報酬指數  14,424.98
# 8      臺灣就業99報酬指數   9,060.30
# 9     臺灣高薪100報酬指數   7,684.73
# 10     未含金融電子報酬指數  23,089.22
# 11     小型股300報酬指數   7,810.34
# 12        水泥類報酬指數     269.77
# 13        食品類報酬指數   2,424.72
# 14        塑膠類報酬指數     403.50
# 15      紡織纖維類報酬指數     789.34
# 16      電機機械類報酬指數     241.12
# 17      電器電纜類報酬指數      64.60
# 18    化學生技醫療類報酬指數     139.66
# 19        化學類報酬指數     157.50
# 20      生技醫療類報酬指數      82.15
# 21      玻璃陶瓷類報酬指數      37.06
# 22        造紙類報酬指數     256.79
# 23        鋼鐵類報酬指數     149.18
# 24        橡膠類報酬指數     421.99
# 25        汽車類報酬指數     435.28
# 26      電子工業類報酬指數     818.28
# 27       半導體類報酬指數     322.41
# 28   電腦及週邊設備類報酬指數     182.74
# 29        光電類報酬指數      51.03
# 30      通信網路類報酬指數     243.94
# ...
