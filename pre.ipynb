# %%
import pandas as pd

# %%
df_list = []
for i in range(0,5):
    this_df = pd.read_csv(f'high_valuation/train_{i}.csv')
    df_list.append(this_df)
df = pd.concat(df_list)

# %%
df['type'] = 'TRAIN'

# %%
df.describe()
# Out:
#          close_day1     high_day1      low_day1     open_day1      vol_day1  \
# count  1.169159e+06  1.169159e+06  1.169159e+06  1.169159e+06  1.169159e+06
# mean   6.232777e-02  6.202933e-02  6.244851e-02  6.250605e-02  1.140494e-01
# std    7.788620e-02  7.775821e-02  7.785230e-02  7.811119e-02  2.800140e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.824959e-02  1.807393e-02  1.830509e-02  1.826764e-02  9.910278e-02
# 50%    3.851530e-02  3.821285e-02  3.865670e-02  3.863142e-02  1.104368e-01
# 75%    7.672048e-02  7.614684e-02  7.699563e-02  7.695087e-02  1.259247e-01
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#           VWAP_day1      ma7_day1     ma21_day1    26ema_day1    12ema_day1  \
# count  1.169159e+06  1.169159e+06  1.169159e+06  1.169159e+06  1.169159e+06
# mean   6.485818e-02  6.303254e-02  6.299753e-02  6.345146e-02  6.310659e-02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1169159 entries, 0 to 140860
# Columns: 585 entries, close_day1 to type
# dtypes: float64(580), int64(3), object(2)
# memory usage: 5.1+ GB

# %%
df2_list = []
for i in range(0,5):
    this_df = pd.read_csv(f'high_valuation/val_{i}.csv')
    df2_list.append(this_df)
df2 = pd.concat(df2_list)

# %%
df2['type'] = 'VALIDATE'

# %%
df2.describe()
# Out:
#           close_day1      high_day1       low_day1      open_day1  \
# count  196193.000000  196193.000000  196193.000000  196193.000000
# mean        0.085735       0.085147       0.085989       0.085946
# std         0.105823       0.105461       0.105707       0.105900
# min         0.001011       0.000986       0.001015       0.001007
# 25%         0.024391       0.024151       0.024575       0.024466
# 50%         0.053058       0.052571       0.053321       0.053227
# 75%         0.103793       0.103112       0.103983       0.104057
# max         1.615203       1.595316       1.590507       1.584507
#
#             vol_day1      VWAP_day1       ma7_day1      ma21_day1  \
# count  196193.000000  196193.000000  196193.000000  196193.000000
# mean        0.107911       0.088235       0.086494       0.086207
# std         0.022675       0.105814       0.106609       0.106142
# min        -0.026145       0.000000       0.001014       0.001028
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196193 entries, 0 to 29343
# Columns: 585 entries, close_day1 to type
# dtypes: float64(580), int64(3), object(2)
# memory usage: 877.1+ MB

# %%
df3_list = []
for i in range(0,5):
    this_df = pd.read_csv(f'high_valuation/test_{i}.csv')
    df3_list.append(this_df)
df3 = pd.concat(df3_list)

# %%
df3['type'] = 'TEST'

# %%
df3.describe()
# Out:
#           close_day1      high_day1       low_day1      open_day1  \
# count  259569.000000  259569.000000  259569.000000  259569.000000
# mean        0.095663       0.095013       0.095837       0.095946
# std         0.119977       0.119387       0.119759       0.120188
# min         0.001399       0.001399       0.001382       0.001386
# 25%         0.028518       0.028191       0.028726       0.028625
# 50%         0.056359       0.055818       0.056725       0.056557
# 75%         0.111604       0.111238       0.111642       0.112048
# max         1.735590       1.714609       1.726560       1.723188
#
#             vol_day1      VWAP_day1       ma7_day1      ma21_day1  \
# count  259569.000000  259569.000000  259569.000000  259569.000000
# mean        0.109067       0.098106       0.096946       0.097465
# std         0.027156       0.119721       0.121942       0.123208
# min        -0.125823       0.000000       0.001432       0.001577
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 259569 entries, 0 to 42048
# Columns: 585 entries, close_day1 to type
# dtypes: float64(580), int64(3), object(2)
# memory usage: 1.1+ GB

# %%
df.columns
# Out:
# Index(['close_day1', 'high_day1', 'low_day1', 'open_day1', 'vol_day1',
#        'VWAP_day1', 'ma7_day1', 'ma21_day1', '26ema_day1', '12ema_day1',
#        ...
#        'foreign_buy_kurtosis_day20', 'investment_buy_skew_day20',
#        'investment_buy_kurtosis_day20', 'dealer_buy_skew_day20',
#        'dealer_buy_kurtosis_day20', 'Y', 'ts', 'StockNo', 'cluster', 'type'],
#       dtype='object', length=585)

# %%
df_complete = pd.concat([df,df2,df3])

# %%
df_complete.describe()

# %%
df_complete.to_csv('high_val_cluster_complete.csv', index=False)

# %%
df_test = pd.read_csv(r'D:\OneDrive - SinoPac\training\train_large.csv')

# %%
df_test
# Out:
#         open_day1  high_day1  low_day1  close_day1  vol_day1  VWAP_day1  \
# 0        0.002263   0.002303  0.002237    0.002256  0.225242   0.003017
# 1        0.002259   0.002298  0.002232    0.002250  0.224382   0.003020
# 2        0.002253   0.002292  0.002225    0.002243  0.225996   0.003019
# 3        0.002245   0.002284  0.002218    0.002234  0.228876   0.003013
# 4        0.002240   0.002278  0.002212    0.002227  0.230907   0.003015
# ...           ...        ...       ...         ...       ...        ...
# 888054   0.013860   0.013885  0.013982    0.013887  0.224440   0.011935
# 888055   0.013936   0.013965  0.014055    0.013961  0.217818   0.011993
# 888056   0.013999   0.014031  0.014117    0.014022  0.216852   0.012041
# 888057   0.014048   0.014081  0.014165    0.014070  0.220787   0.012079
# 888058   0.014089   0.014123  0.014207    0.014110  0.237793   0.012111
#
#         index_open_day1  index_high_day1  index_low_day1  index_close_day1  \
# ...

# %%
split_index = int(888059/2)

# %%
df_test1 = df_test.iloc[:split_index]

# %%
df_test2 = df_test.iloc[split_index:]

# %%
df_test1
# Out:
#         open_day1  high_day1  low_day1  close_day1  vol_day1  VWAP_day1  \
# 0        0.002263   0.002303  0.002237    0.002256  0.225242   0.003017
# 1        0.002259   0.002298  0.002232    0.002250  0.224382   0.003020
# 2        0.002253   0.002292  0.002225    0.002243  0.225996   0.003019
# 3        0.002245   0.002284  0.002218    0.002234  0.228876   0.003013
# 4        0.002240   0.002278  0.002212    0.002227  0.230907   0.003015
# ...           ...        ...       ...         ...       ...        ...
# 444024   0.004831   0.004836  0.004867    0.004833  0.220597   0.014529
# 444025   0.004796   0.004800  0.004831    0.004797  0.221921   0.014429
# 444026   0.004762   0.004765  0.004796    0.004762  0.220310   0.014325
# 444027   0.004723   0.004725  0.004756    0.004723  0.219521   0.014211
# 444028   0.004681   0.004683  0.004713    0.004681  0.217897   0.014088
#
#         index_open_day1  index_high_day1  index_low_day1  index_close_day1  \
# ...

# %%
df_test2
# Out:
#         open_day1  high_day1  low_day1  close_day1  vol_day1  VWAP_day1  \
# 444029   0.004646   0.004648  0.004678    0.004646  0.216993   0.013988
# 444030   0.004620   0.004621  0.004651    0.004620  0.216770   0.013913
# 444031   0.004598   0.004598  0.004629    0.004598  0.221043   0.013849
# 444032   0.004583   0.004583  0.004613    0.004582  0.219267   0.013806
# 444033   0.004567   0.004567  0.004597    0.004567  0.220036   0.013763
# ...           ...        ...       ...         ...       ...        ...
# 888054   0.013860   0.013885  0.013982    0.013887  0.224440   0.011935
# 888055   0.013936   0.013965  0.014055    0.013961  0.217818   0.011993
# 888056   0.013999   0.014031  0.014117    0.014022  0.216852   0.012041
# 888057   0.014048   0.014081  0.014165    0.014070  0.220787   0.012079
# 888058   0.014089   0.014123  0.014207    0.014110  0.237793   0.012111
#
#         index_open_day1  index_high_day1  index_low_day1  index_close_day1  \
# ...

# %%
df_test1.to_csv(r'D:\OneDrive - SinoPac\training\train_large_1.csv', index=False)

# %%
df_test2.to_csv(r'D:\OneDrive - SinoPac\training\train_large_2.csv', index=False)

# %%
df_test.isnull().values.any()

# %%
df_test.describe()

# %%
df_test1 = pd.read_csv(r'D:\OneDrive - SinoPac\training\train_large.csv')

# %%
df_test2 = pd.read_csv(r'D:\OneDrive - SinoPac\training\val_large.csv')

# %%
df_complete = pd.concat([df_test1,df_test2])

# %%
df_complete
# Out:
#         open_day1  high_day1  low_day1  close_day1  vol_day1  VWAP_day1  \
# 0        0.002263   0.002303  0.002237    0.002256  0.225242   0.003017
# 1        0.002259   0.002298  0.002232    0.002250  0.224382   0.003020
# 2        0.002253   0.002292  0.002225    0.002243  0.225996   0.003019
# 3        0.002245   0.002284  0.002218    0.002234  0.228876   0.003013
# 4        0.002240   0.002278  0.002212    0.002227  0.230907   0.003015
# ...           ...        ...       ...         ...       ...        ...
# 196140   0.010532   0.010478  0.010666    0.010543  0.221141   0.009114
# 196141   0.010523   0.010468  0.010657    0.010534  0.220598   0.009103
# 196142   0.010514   0.010460  0.010648    0.010525  0.220610   0.009093
# 196143   0.010506   0.010452  0.010640    0.010517  0.220292   0.009083
# 196144   0.010498   0.010444  0.010632    0.010509  0.219689   0.009074
#
#         index_open_day1  index_high_day1  index_low_day1  index_close_day1  \
# ...

# %%
df_complete.to_csv(r'D:\OneDrive - SinoPac\training\large_train_val.csv', index=False)

# %%
prob_list = []
for i in range (len(df_test1.columns)):
    if '%' in df_test1.columns[i]:
        prob_list.append(df_test1.columns[i])

# %%
fixed_list = [p.replace('%','') for p in prob_list]

# %%
fixed_dict = dict(zip(prob_list,fixed_list))

# %%
fixed_dict
# Out:
# {'SO%k5_day1': 'SOk5_day1',
#  'SO%d3_day1': 'SOd3_day1',
#  'SO%k5_day2': 'SOk5_day2',
#  'SO%d3_day2': 'SOd3_day2',
#  'SO%k5_day3': 'SOk5_day3',
#  'SO%d3_day3': 'SOd3_day3',
#  'SO%k5_day4': 'SOk5_day4',
#  'SO%d3_day4': 'SOd3_day4',
#  'SO%k5_day5': 'SOk5_day5',
#  'SO%d3_day5': 'SOd3_day5',
#  'SO%k5_day6': 'SOk5_day6',
#  'SO%d3_day6': 'SOd3_day6',
#  'SO%k5_day7': 'SOk5_day7',
#  'SO%d3_day7': 'SOd3_day7',
#  'SO%k5_day8': 'SOk5_day8',
#  'SO%d3_day8': 'SOd3_day8',
#  'SO%k5_day9': 'SOk5_day9',
#  'SO%d3_day9': 'SOd3_day9',
#  'SO%k5_day10': 'SOk5_day10',
#  'SO%d3_day10': 'SOd3_day10',
#  'SO%k5_day11': 'SOk5_day11',
#  'SO%d3_day11': 'SOd3_day11',
#  'SO%k5_day12': 'SOk5_day12',
#  'SO%d3_day12': 'SOd3_day12',
#  'SO%k5_day13': 'SOk5_day13',
#  'SO%d3_day13': 'SOd3_day13',
#  'SO%k5_day14': 'SOk5_day14',
#  'SO%d3_day14': 'SOd3_day14',
#  'SO%k5_day15': 'SOk5_day15',
#  'SO%d3_day15': 'SOd3_day15',
#  'SO%k5_day16': 'SOk5_day16',
#  'SO%d3_day16': 'SOd3_day16',
# ...

# %%
df_test1 = df_test1.rename(columns=fixed_dict)

# %%
df_test1.to_csv('high_val_cluster_complete_2.csv', index=False)

# %%
df_test1.describe()
# Out:
#           close_day1      high_day1       low_day1      open_day1  \
# count  812461.000000  812461.000000  812461.000000  812461.000000
# mean        0.092866       0.092511       0.093052       0.093204
# std         0.105522       0.105294       0.105374       0.105754
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.032649       0.032454       0.032802       0.032787
# 50%         0.059825       0.059538       0.060084       0.060076
# 75%         0.110224       0.109892       0.110439       0.110669
# max         1.735590       1.714609       1.726560       1.723188
#
#             vol_day1      VWAP_day1       ma7_day1      ma21_day1  \
# count  812461.000000  812461.000000  812461.000000  812461.000000
# mean        0.107898       0.095987       0.093779       0.093310
# std         0.030911       0.105530       0.106725       0.106738
# min        -0.125823       0.000000       0.000000       0.000000
# ...
